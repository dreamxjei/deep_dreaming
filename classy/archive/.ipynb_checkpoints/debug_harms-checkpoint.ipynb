# %% [markdown]
# # debug_risser

# %%
import os
import random

import numpy as np
import pandas as pd
import pydicom as dicom
import matplotlib.pyplot as plt

# %%
data_orig = '../data/harms'
sites = os.listdir(data_orig)
print(sites)
# Out:
# ['DEL pre&1yr', 'STL pre&1yr', 'PHI pre&1yr', 'CMC pre&1yr', 'PHC pre&1yr', 'MSJ pre&1yr', 'BOS pre&1yr']

# %%
# dict with keys as 3-letter location ID's and entries as case folders
cases = {}
total_num_cases = 0
for site in sites:
    prefix = site.split()[0]
    sitedir = os.path.join(data_orig, site)
    filenames = os.listdir(sitedir)
    cases_iter = []
    # make format uniform for pre/1year labels
#     for filename in filenames:
        # loremipsum
    
    random.shuffle(cases_iter)  # shuffle!
    total_num_cases += len(cases_iter)
    cases[prefix] = cases_iter
    
print(total_num_cases, 'total cases')
# Out:
# 720 total cases

# %%
# make num of train, val, test directories

val_num = int(np.ceil(total_num_cases * 0.1))
test_num = int(np.ceil(total_num_cases * 0.2))
train_num = total_num_cases - val_num - test_num
print('train:',train_num,'val:',val_num,'test:',test_num)
# Out:
# train: 504 val: 72 test: 144

# %% [markdown]
# ### look at no hand sample

# %%
idir = '../data/harms/DEL pre&1yr/DELAISY0641-AZ (PREOP) (No hand)'

# %%
ifiles = os.listdir(idir)
print(ifiles)
# Out:
# ['DE641.preop0001^Patient_000002_DX_PROFIL.dcm', 'DE641.PREOP0001^PATIENT_000001_DX_FACE_132025088461735708_SC.dcm', 'DE641.preop0001^Patient_000001_DX_FACE.dcm', 'DE641.preop0001^Patient_sterEOS_Excel_Report17052019_1008_36.xlsx']

# %%
for ifile in ifiles:
    if not ifile.endswith('.dcm'):
        continue
    filepath = os.path.join(idir, ifile)
    print('showing',filepath)
    raw = dicom.read_file(filepath)
    img = raw.pixel_array.astype(np.int32)
    print(np.shape(img))
    plt.figure(figsize=(12,8))
    plt.imshow(img)
    plt.show()
# Out:
# showing ../data/harms/DEL pre&1yr/DELAISY0641-AZ (PREOP) (No hand)/DE641.preop0001^Patient_000002_DX_PROFIL.dcm
# (3901, 1764)
# showing ../data/harms/DEL pre&1yr/DELAISY0641-AZ (PREOP) (No hand)/DE641.PREOP0001^PATIENT_000001_DX_FACE_132025088461735708_SC.dcm
# (1272, 2290)
# showing ../data/harms/DEL pre&1yr/DELAISY0641-AZ (PREOP) (No hand)/DE641.preop0001^Patient_000001_DX_FACE.dcm
# (3901, 2280)
# showing ../data/harms/DEL pre&1yr/DELAISY0641-AZ (PREOP) (No hand)/DE641.preop0001^Patient_sterEOS_Excel_Report17052019_1008_36.xlsx
# ---------------------------------------------------------------------------
# InvalidDicomError                         Traceback (most recent call last)
# <ipython-input-21-6b49cf972059> in <module>
#       2     filepath = os.path.join(idir, ifile)
#       3     print('showing',filepath)
# ----> 4     raw = dicom.read_file(filepath)
#       5     img = raw.pixel_array.astype(np.int32)
#       6     print(np.shape(img))
#
# ~/.conda/envs/arcade/lib/python3.8/site-packages/pydicom/filereader.py in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#     868         stop_when = _at_pixel_data
#     869     try:
# --> 870         dataset = read_partial(fp, stop_when, defer_size=defer_size,
#     871                                force=force, specific_tags=specific_tags)
#     872     finally:
#
# ~/.conda/envs/arcade/lib/python3.8/site-packages/pydicom/filereader.py in read_partial(fileobj, stop_when, defer_size, force, specific_tags)
#     666
#     667     # Read preamble (if present)
# --> 668     preamble = read_preamble(fileobj, force)
#     669     # Read any File Meta Information group (0002,eeee) elements (if present)
#     670     file_meta_dataset = _read_file_meta_info(fileobj)
#
# ~/.conda/envs/arcade/lib/python3.8/site-packages/pydicom/filereader.py in read_preamble(fp, force)
#     619         fp.seek(0)
#     620     elif magic != b"DICM" and not force:
# --> 621         raise InvalidDicomError("File is missing DICOM File Meta Information "
#     622                                 "header or the 'DICM' prefix is missing from "
#     623                                 "the header. Use force=True to force reading.")
#
# InvalidDicomError: File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading.
